# %%
import numpy as np
import pandas as pd
import pyfpgrowth as pf

# %%
df= pd.read_csv('store_data.csv', header=None)
df
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
recordList=df.values.tolist()
cleanList= [[x for x in sublist if str(x) != 'nan']for sublist in recordList]
cleanList[1]
# Out:
# ['burgers', 'meatballs', 'eggs']

# %%
FrequentPattern=pf.find_frequent_patterns(transactions=cleanList,support_threshold=200)
#print(FrequentPattern)
Rules=pf.generate_association_rules(patterns=FrequentPattern,confidence_threshold=0.2)
print(Rules)
# Out:
# {('olive oil',): (('mineral water',), 0.4190283400809717), ('cake',): (('mineral water',), 0.33881578947368424), ('burgers',): (('eggs',), 0.3302752293577982), ('pancakes',): (('mineral water',), 0.3548387096774194), ('mineral water',): (('eggs',), 0.21364653243847875), ('eggs',): (('mineral water',), 0.28338278931750743)}
